# %% [markdown]
# ## Week 8 - Session 1: Hidden Markov Model (HMM)
#  - Explore an intelligent tutoring system called Deep Thought.
#  - Deep Thought takes two actions, providing 1) Problem Solving (PS) and 2) Work Example (WE), based on the students' state for their best learning gain.

# %%
__author__ = 'yemao'
from HMM import hmm
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression, LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, recall_score, roc_auc_score, mean_squared_error

# %% [markdown]
# ### Data

# %%
np.random.seed(1000)
folder = "assignment_data/"             # Specify your folder here
qlg_y = np.load(folder + "y_qlg.npy")   # target label for learning gain
post_y = np.load(folder + "post_test.npy", allow_pickle=True)   # target value for post-test score
qlg_test_actual, post_test_actual = [], []

# %% [markdown]
# ### Training (5-CV)

# %%
# %%time
kf = KFold(n_splits=5, shuffle=True)
qlg_train_pred, post_train_pred = [], []
qlg_train_actual, post_train_actual = [], []
qlg_test_pred, post_test_pred = [], []

numkc = 7      # Q2-1. change number of kc for different data set

for train_index, test_index in kf.split(qlg_y):
    print("======================================================")
    qlg_y_train, qlg_y_test = qlg_y[train_index], qlg_y[test_index]
    post_y_train, post_y_test = post_y[train_index], post_y[test_index]

    # symbols here refers to two different observations:
    # 1: correct, 0: incorrect
    symbols = [['0', '1']]
    
    #------------------------------------------
    # Q2-2. Explore different parameters: 
    #   1) Pi : Initial staste prob.
    #   2) T : State transition prob.
    # -----------------------------------------

    #h = hmm(2, Pi=np.array([0.5, 0.5]), T=np.array([[0.86, 0.14], [0.09, 0.91]]), obs_symbols=symbols)
    
    
    nlg_train = [[] for x in range(numkc)]
    nlg_test = [[] for x in range(numkc)]
    
    for i in range(numkc):
        print("-----------------------------------------")
        print(" KC: {}".format(i))
        h = hmm(2, Pi=np.array([0.5, 0.5]), T=np.array([[0.86, 0.14], [0.09, 0.91]]), obs_symbols=symbols)
        
        X = np.load(folder + "perf_kc" + str(i+1) + ".npy", allow_pickle=True)
        X_train, X_test = X[train_index], X[test_index]

        train = [each for each in X_train if each]
        test = [each for each in X_test if each]
        
        
        if train and test:
            h.baum_welch(train, debug=False)        # Baum-Welch algorithm : training part
        
        
        nlg_train[i].extend(h.predict_nlg(X_train))
        nlg_test[i].extend(h.predict_nlg(X_test))

    print(len(nlg_train), len(nlg_train[0]))
    nlg_train = np.transpose(nlg_train)
    nlg_test = np.transpose(nlg_test)

    nlg_train = pd.DataFrame(nlg_train).fillna(value=0)
    nlg_test = pd.DataFrame(nlg_test).fillna(value=0)

    # ---------------------------------------------------------
    # logistic regression for learning gain prediction
    logreg = LogisticRegression()                   
    logreg.fit(nlg_train, qlg_y_train)
    predict = logreg.predict(nlg_train)
    qlg_train_pred.extend([each for each in predict])
    qlg_train_actual.extend(qlg_y_train)

    predict = logreg.predict(nlg_test)
    # print (logreg.predict_proba(nlg_test))
    qlg_test_pred.extend([each for each in predict])
    qlg_test_actual.extend(qlg_y_test)


    lg = LinearRegression()              # linear regression for post-test scores prediction
    lg.fit(nlg_train, post_y_train)
    predict = lg.predict(nlg_train)
    post_train_pred.extend([each for each in predict])
    post_train_actual.extend(post_y_train)

    predict = lg.predict(nlg_test)
    post_test_pred.extend([each for each in predict])
    post_test_actual.extend(post_y_test)
# Out:
# ======================================================
# -----------------------------------------
#  KC: 0
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.51479232, 0.48520768],
#        [0.48570504, 0.51429496]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -568.7291398968408
# Epoch 10
# -321.11940400362545
# Epoch 20
# -319.2228187712828
# Epoch 30
# -317.06799377778214
# Epoch 40
# -315.14243950245964
# Epoch 50
# -313.40541069958545
# Epoch 60
# -312.6209314296527
# Epoch 70
# -312.42450122070926
# Epoch 80
# -312.3763035951694
# The loglikelihood improvement falls below threshold, training terminates at epoch 88!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[8.79366606e-01 1.20633394e-01]
#  [6.67097486e-05 9.99933290e-01]]
# 5) The emission probability matrix E:
# [array([[1.94880587e-01, 8.05119413e-01],
#        [4.03687992e-06, 9.99995963e-01]])]
# 6) The initial state probability Pi:
# [9.99512502e-01 4.87497721e-04]
#
# -----------------------------------------
#  KC: 1
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.39113299, 0.60886701],
#        [0.18929166, 0.81070834]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -901.8799559743076
# Epoch 10
# -803.5923256646619
# Epoch 20
# -796.751573201906
# Epoch 30
# -794.3623872245458
# Epoch 40
# -793.4934695295324
# Epoch 50
# -793.1580938628806
# Epoch 60
# -793.0427265596651
# Epoch 70
# -793.0064661218133
# The loglikelihood improvement falls below threshold, training terminates at epoch 76!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.99973875e-01 2.61246668e-05]
#  [1.02445662e-01 8.97554338e-01]]
# 5) The emission probability matrix E:
# [array([[0.19985492, 0.80014508],
#        [0.03404405, 0.96595595]])]
# 6) The initial state probability Pi:
# [0.14897568 0.85102432]
#
# -----------------------------------------
#  KC: 2
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.62759268, 0.37240732],
#        [0.63515085, 0.36484915]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -6315.132899635416
# Epoch 10
# -2820.6367417202837
# Epoch 20
# -2811.0523184811177
# Epoch 30
# -2802.991562315524
# Epoch 40
# -2792.3973027202696
# Epoch 50
# -2780.3134844987862
# Epoch 60
# -2774.4950164401134
# Epoch 70
# -2773.0170841816034
# Epoch 80
# -2772.704252494824
# Epoch 90
# -2772.641071201352
# The loglikelihood improvement falls below threshold, training terminates at epoch 97!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.78910528e-01 2.10894720e-02]
#  [1.03527055e-05 9.99989647e-01]]
# 5) The emission probability matrix E:
# [array([[0.08828206, 0.91171794],
#        [0.21486751, 0.78513249]])]
# 6) The initial state probability Pi:
# [9.99997656e-01 2.34432886e-06]
#
# -----------------------------------------
#  KC: 3
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.77278511, 0.22721489],
#        [0.04125967, 0.95874033]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -645.0943492545192
# Epoch 10
# -492.53490262729287
# Epoch 20
# -491.6950508279801
# Epoch 30
# -490.36063937150067
# Epoch 40
# -487.3421676751709
# Epoch 50
# -481.2515632854036
# Epoch 60
# -477.9583202285697
# Epoch 70
# -477.68917972730014
# Epoch 80
# -477.62535568554665
# Epoch 90
# -477.5304785483428
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.18237384 0.81762616]
#  [0.39780917 0.60219083]]
# 5) The emission probability matrix E:
# [array([[0.48434094, 0.51565906],
#        [0.00966905, 0.99033095]])]
# 6) The initial state probability Pi:
# [0.01306211 0.98693789]
#
# -----------------------------------------
#  KC: 4
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.45820404, 0.54179596],
#        [0.02898015, 0.97101985]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -1089.2574161177104
# Epoch 10
# -980.0709273604325
# Epoch 20
# -969.2515372417878
# Epoch 30
# -964.0470956875987
# Epoch 40
# -962.6580986080809
# Epoch 50
# -962.2522158493216
# Epoch 60
# -962.1300842109924
# Epoch 70
# -962.0934066676828
# The loglikelihood improvement falls below threshold, training terminates at epoch 76!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.38862759e-01 6.11372412e-02]
#  [3.80784962e-05 9.99961922e-01]]
# 5) The emission probability matrix E:
# [array([[0.16185377, 0.83814623],
#        [0.03394802, 0.96605198]])]
# 6) The initial state probability Pi:
# [9.99999403e-01 5.97033830e-07]
#
# -----------------------------------------
#  KC: 5
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.53590435, 0.46409565],
#        [0.23011093, 0.76988907]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -2884.3844993505923
# Epoch 10
# -2238.175597871475
# Epoch 20
# -2232.122930111944
# Epoch 30
# -2224.430793152932
# Epoch 40
# -2218.047496016623
# Epoch 50
# -2214.5989064876226
# Epoch 60
# -2213.181539580368
# Epoch 70
# -2212.6258086810167
# Epoch 80
# -2212.3808238921747
# Epoch 90
# -2212.258223165413
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.99306740e-01 6.93260475e-04]
#  [2.12810616e-02 9.78718938e-01]]
# 5) The emission probability matrix E:
# [array([[0.17279009, 0.82720991],
#        [0.07019992, 0.92980008]])]
# 6) The initial state probability Pi:
# [1.55101249e-04 9.99844899e-01]
#
# -----------------------------------------
#  KC: 6
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.55052926, 0.44947074],
#        [0.28197914, 0.71802086]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -3255.9194860208017
# Epoch 10
# -2557.3660987542607
# Epoch 20
# -2554.8023610231435
# Epoch 30
# -2551.97367510629
# Epoch 40
# -2548.316021548219
# Epoch 50
# -2544.054649776536
# Epoch 60
# -2540.097601695992
# Epoch 70
# -2537.510690505345
# Epoch 80
# -2536.279184991865
# Epoch 90
# -2535.753420381399
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.99602587 0.00397413]
#  [0.03844659 0.96155341]]
# 5) The emission probability matrix E:
# [array([[0.18710845, 0.81289155],
#        [0.08115324, 0.91884676]])]
# 6) The initial state probability Pi:
# [2.21674385e-06 9.99997783e-01]
#
# 7 107
# ======================================================
# -----------------------------------------
#  KC: 0
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.72741345, 0.27258655],
#        [0.85660294, 0.14339706]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -1105.0541584314346
# Epoch 10
# -312.47563895579776
# Epoch 20
# -312.0396883188817
# Epoch 30
# -311.41340549376366
# Epoch 40
# -310.69337805510804
# Epoch 50
# -309.93185964493085
# Epoch 60
# -309.1483752032812
# Epoch 70
# -308.35476017528
# Epoch 80
# -307.57732392835345
# Epoch 90
# -306.89580806535173
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.99752336 0.00247664]
#  [0.13549949 0.86450051]]
# 5) The emission probability matrix E:
# [array([[0.02168115, 0.97831885],
#        [0.18671038, 0.81328962]])]
# 6) The initial state probability Pi:
# [0.02688041 0.97311959]
#
# -----------------------------------------
#  KC: 1
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.82851707, 0.17148293],
#        [0.365096  , 0.634904  ]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -1312.0770299818082
# Epoch 10
# -846.6183329334466
# Epoch 20
# -846.0670711612236
# Epoch 30
# -844.7126735997075
# Epoch 40
# -840.0335911431372
# Epoch 50
# -833.8016279196341
# Epoch 60
# -831.2528329729042
# Epoch 70
# -830.5753846980525
# Epoch 80
# -830.4077131068184
# Epoch 90
# -830.3644881706765
# The loglikelihood improvement falls below threshold, training terminates at epoch 97!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.99924021e-01 7.59790715e-05]
#  [9.17757192e-02 9.08224281e-01]]
# 5) The emission probability matrix E:
# [array([[0.20232278, 0.79767722],
#        [0.06785345, 0.93214655]])]
# 6) The initial state probability Pi:
# [9.78938621e-05 9.99902106e-01]
#
# -----------------------------------------
#  KC: 2
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.21442077, 0.78557923],
#        [0.97636055, 0.02363945]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -3989.12995103375
# Epoch 10
# -2903.1453022993887
# Epoch 20
# -2902.275535748997
# Epoch 30
# -2902.0290061864075
# Epoch 40
# -2901.8724824552787
# Epoch 50
# -2901.7005329751655
# Epoch 60
# -2901.4727010889133
# Epoch 70
# -2901.153827402462
# Epoch 80
# -2900.6947833009694
# Epoch 90
# -2900.0210459913496
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.58580678e-01 4.14193224e-02]
#  [9.99999999e-01 1.23730123e-09]]
# 5) The emission probability matrix E:
# [array([[0.11421974, 0.88578026],
#        [0.90666288, 0.09333712]])]
# 6) The initial state probability Pi:
# [1.00000000e+00 3.35346827e-10]
#
# -----------------------------------------
#  KC: 3
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.2088668 , 0.7911332 ],
#        [0.75577491, 0.24422509]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -717.4876375531583
# Epoch 10
# -524.7034899559713
# Epoch 20
# -524.6054325301521
# Epoch 30
# -524.5038050257517
# Epoch 40
# -524.4029765896496
# Epoch 50
# -524.3025111232677
# Epoch 60
# -524.1927648718793
# Epoch 70
# -524.0605831497463
# Epoch 80
# -523.8892656684782
# Epoch 90
# -523.654174215049
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86866973 0.13133027]
#  [0.46742678 0.53257322]]
# 5) The emission probability matrix E:
# [array([[0.13254351, 0.86745649],
#        [0.24534476, 0.75465524]])]
# 6) The initial state probability Pi:
# [9.99977213e-01 2.27869914e-05]
#
# -----------------------------------------
#  KC: 4
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.27939717, 0.72060283],
#        [0.06838392, 0.93161608]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -1109.4736240508735
# Epoch 10
# -1064.7450494310572
# Epoch 20
# -1054.995084648424
# Epoch 30
# -1051.2481595692202
# Epoch 40
# -1050.1853678743296
# Epoch 50
# -1049.8634734643358
# Epoch 60
# -1049.7682711112088
# Epoch 70
# -1049.7406262646289
# The loglikelihood improvement falls below threshold, training terminates at epoch 74!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.42371562e-01 5.76284381e-02]
#  [3.23256830e-05 9.99967674e-01]]
# 5) The emission probability matrix E:
# [array([[0.1692067 , 0.8307933 ],
#        [0.03811816, 0.96188184]])]
# 6) The initial state probability Pi:
# [9.99999994e-01 6.24034064e-09]
#
# -----------------------------------------
#  KC: 5
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.18478948, 0.81521052],
#        [0.51218078, 0.48781922]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -3007.698944623258
# Epoch 10
# -2322.894211545864
# Epoch 20
# -2313.940736868879
# Epoch 30
# -2304.9423615902697
# Epoch 40
# -2299.427125808268
# Epoch 50
# -2297.3457394353436
# Epoch 60
# -2296.6082398256676
# Epoch 70
# -2296.088460061279
# Epoch 80
# -2295.35881739569
# Epoch 90
# -2294.805813660901
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.83132102e-01 1.68678975e-02]
#  [4.93333658e-05 9.99950667e-01]]
# 5) The emission probability matrix E:
# [array([[0.0643573 , 0.9356427 ],
#        [0.17876058, 0.82123942]])]
# 6) The initial state probability Pi:
# [0.84980798 0.15019202]
#
# -----------------------------------------
#  KC: 6
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.59510318, 0.40489682],
#        [0.6531843 , 0.3468157 ]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -5755.6514383691565
# Epoch 10
# -2696.022059391743
# Epoch 20
# -2687.540346631883
# Epoch 30
# -2682.889188460558
# Epoch 40
# -2678.792511491352
# Epoch 50
# -2675.709852619576
# Epoch 60
# -2673.993262848214
# Epoch 70
# -2673.252362915436
# Epoch 80
# -2672.9613015809805
# Epoch 90
# -2672.84260427535
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.95965312 0.04034688]
#  [0.00444933 0.99555067]]
# 5) The emission probability matrix E:
# [array([[0.07897865, 0.92102135],
#        [0.20016701, 0.79983299]])]
# 6) The initial state probability Pi:
# [0.99772593 0.00227407]
#
# 7 107
# ======================================================
# -----------------------------------------
#  KC: 0
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.51055879, 0.48944121],
#        [0.4773483 , 0.5226517 ]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -568.0961392417548
# Epoch 10
# -320.34448838828894
# Epoch 20
# -317.2541484700645
# Epoch 30
# -315.04588387034033
# Epoch 40
# -314.102374446992
# Epoch 50
# -313.59320589043614
# Epoch 60
# -313.2901220039643
# Epoch 70
# -313.10989496710636
# Epoch 80
# -313.01216506928284
# Epoch 90
# -312.9666004595694
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86523527 0.13476473]
#  [0.0052238  0.9947762 ]]
# 5) The emission probability matrix E:
# [array([[0.1928797 , 0.8071203 ],
#        [0.01077724, 0.98922276]])]
# 6) The initial state probability Pi:
# [9.99986521e-01 1.34794491e-05]
#
# -----------------------------------------
#  KC: 1
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.42442791, 0.57557209],
#        [0.51424162, 0.48575838]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -1314.5975602155834
# Epoch 10
# -784.6858050469679
# Epoch 20
# -777.6161049184583
# Epoch 30
# -775.0781844673824
# Epoch 40
# -774.3434119458134
# Epoch 50
# -774.1704077553227
# Epoch 60
# -774.1325865859662
# The loglikelihood improvement falls below threshold, training terminates at epoch 64!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.08208289e-01 9.17917108e-02]
#  [3.40446130e-05 9.99965955e-01]]
# 5) The emission probability matrix E:
# [array([[0.03799227, 0.96200773],
#        [0.1961519 , 0.8038481 ]])]
# 6) The initial state probability Pi:
# [0.86724952 0.13275048]
#
# -----------------------------------------
#  KC: 2
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.61609597, 0.38390403],
#        [0.60433707, 0.39566293]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -6024.630057477515
# Epoch 10
# -2884.89787834748
# Epoch 20
# -2881.907422654758
# Epoch 30
# -2867.945049909348
# Epoch 40
# -2858.423077702919
# Epoch 50
# -2845.692013244075
# Epoch 60
# -2837.0158669672796
# Epoch 70
# -2834.091984676207
# Epoch 80
# -2833.183924109004
# Epoch 90
# -2832.9349247895852
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.99929096e-01 7.09036419e-05]
#  [1.79013602e-02 9.82098640e-01]]
# 5) The emission probability matrix E:
# [array([[0.23117661, 0.76882339],
#        [0.09579357, 0.90420643]])]
# 6) The initial state probability Pi:
# [1.33289628e-11 1.00000000e+00]
#
# -----------------------------------------
#  KC: 3
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.57491662, 0.42508338],
#        [0.77573131, 0.22426869]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -1140.8737799533035
# Epoch 10
# -517.6797298543607
# Epoch 20
# -517.5846059562591
# Epoch 30
# -517.0574497317574
# Epoch 40
# -513.0832268359884
# Epoch 50
# -505.4959475016969
# Epoch 60
# -504.03091507614886
# The loglikelihood improvement falls below threshold, training terminates at epoch 69!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.99132517 0.00867483]
#  [0.7715067  0.2284933 ]]
# 5) The emission probability matrix E:
# [array([[1.74334703e-01, 8.25665297e-01],
#        [1.89437130e-05, 9.99981056e-01]])]
# 6) The initial state probability Pi:
# [0.10429064 0.89570936]
#
# -----------------------------------------
#  KC: 4
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.74087747, 0.25912253],
#        [0.50763671, 0.49236329]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -2568.1655010764566
# Epoch 10
# -1007.1662836816314
# Epoch 20
# -1001.340150771477
# Epoch 30
# -989.6931021680518
# Epoch 40
# -982.3086046154609
# Epoch 50
# -981.1620443125133
# Epoch 60
# -980.9670085225736
# Epoch 70
# -980.9128921436745
# Epoch 80
# -980.8952371290209
# The loglikelihood improvement falls below threshold, training terminates at epoch 81!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.34591500e-01 6.54084998e-02]
#  [4.16008766e-05 9.99958399e-01]]
# 5) The emission probability matrix E:
# [array([[0.16370811, 0.83629189],
#        [0.03730795, 0.96269205]])]
# 6) The initial state probability Pi:
# [9.99999607e-01 3.92798653e-07]
#
# -----------------------------------------
#  KC: 5
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.97679479, 0.02320521],
#        [0.56308167, 0.43691833]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -5707.260545986786
# Epoch 10
# -2342.1093859986
# Epoch 20
# -2340.8635184155687
# Epoch 30
# -2317.3773165392304
# Epoch 40
# -2300.3684193390736
# Epoch 50
# -2297.1108423718624
# Epoch 60
# -2295.6364169380868
# Epoch 70
# -2295.203115866635
# Epoch 80
# -2295.0874157665253
# Epoch 90
# -2295.0421497740176
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.99765754e-01 2.34245604e-04]
#  [1.93899894e-02 9.80610011e-01]]
# 5) The emission probability matrix E:
# [array([[0.19190846, 0.80809154],
#        [0.06946277, 0.93053723]])]
# 6) The initial state probability Pi:
# [2.50858604e-14 1.00000000e+00]
#
# -----------------------------------------
#  KC: 6
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.62701349, 0.37298651],
#        [0.00281964, 0.99718036]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -3125.992929081027
# Epoch 10
# -2654.5175451391256
# Epoch 20
# -2649.145318061797
# Epoch 30
# -2647.47229943403
# Epoch 40
# -2645.810053156519
# Epoch 50
# -2643.7879169216976
# Epoch 60
# -2641.337476619247
# Epoch 70
# -2638.4939960148827
# Epoch 80
# -2635.417169881359
# Epoch 90
# -2632.3836093549626
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.96486199 0.03513801]
#  [0.08538962 0.91461038]]
# 5) The emission probability matrix E:
# [array([[0.20610086, 0.79389914],
#        [0.0623826 , 0.9376174 ]])]
# 6) The initial state probability Pi:
# [1.89988083e-08 9.99999981e-01]
#
# 7 107
# ======================================================
# -----------------------------------------
#  KC: 0
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.32927327, 0.67072673],
#        [0.38948037, 0.61051963]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -429.95054628553146
# Epoch 10
# -324.6125488091712
# Epoch 20
# -324.32969324811575
# Epoch 30
# -322.9144654462391
# Epoch 40
# -319.90402880562044
# Epoch 50
# -318.01834976808425
# Epoch 60
# -317.05414127328373
# Epoch 70
# -316.56183258661946
# Epoch 80
# -316.3629378850766
# Epoch 90
# -316.2848569682699
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.87780788 0.12219212]
#  [0.0080443  0.9919557 ]]
# 5) The emission probability matrix E:
# [array([[0.19719586, 0.80280414],
#        [0.00245887, 0.99754113]])]
# 6) The initial state probability Pi:
# [9.99985573e-01 1.44270832e-05]
#
# -----------------------------------------
#  KC: 1
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.20660806, 0.79339194],
#        [0.28264968, 0.71735032]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -891.8306160520258
# Epoch 10
# -819.4578772682233
# Epoch 20
# -812.7588790128129
# Epoch 30
# -810.8076439868111
# Epoch 40
# -810.3745935293753
# Epoch 50
# -810.2873890770547
# The loglikelihood improvement falls below threshold, training terminates at epoch 59!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[8.91505118e-01 1.08494882e-01]
#  [1.68429098e-05 9.99983157e-01]]
# 5) The emission probability matrix E:
# [array([[0.04087871, 0.95912129],
#        [0.20663164, 0.79336836]])]
# 6) The initial state probability Pi:
# [0.85924319 0.14075681]
#
# -----------------------------------------
#  KC: 2
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.29299016, 0.70700984],
#        [0.19347557, 0.80652443]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -3000.9471796407447
# Epoch 10
# -2857.5953344516297
# Epoch 20
# -2847.546085029373
# Epoch 30
# -2836.726246023116
# Epoch 40
# -2829.2631333731133
# Epoch 50
# -2826.16249839981
# Epoch 60
# -2825.202001263277
# Epoch 70
# -2824.943793754041
# Epoch 80
# -2824.877204520411
# The loglikelihood improvement falls below threshold, training terminates at epoch 89!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.99982268e-01 1.77316895e-05]
#  [2.03840357e-02 9.79615964e-01]]
# 5) The emission probability matrix E:
# [array([[0.23010416, 0.76989584],
#        [0.09597107, 0.90402893]])]
# 6) The initial state probability Pi:
# [2.32192017e-15 1.00000000e+00]
#
# -----------------------------------------
#  KC: 3
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.05518813, 0.94481187],
#        [0.48736438, 0.51263562]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -571.4326585597154
# Epoch 10
# -486.1267593937399
# Epoch 20
# -483.7988620908827
# Epoch 30
# -478.0827359846406
# Epoch 40
# -472.26598118380304
# Epoch 50
# -471.5023166522153
# Epoch 60
# -471.3415618126222
# Epoch 70
# -471.23849999221596
# Epoch 80
# -471.1452473914321
# Epoch 90
# -471.0600442374697
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.24215373 0.75784627]
#  [0.02106295 0.97893705]]
# 5) The emission probability matrix E:
# [array([[0.00849479, 0.99150521],
#        [0.18150032, 0.81849968]])]
# 6) The initial state probability Pi:
# [0.99860341 0.00139659]
#
# -----------------------------------------
#  KC: 4
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.48529153, 0.51470847],
#        [0.54841967, 0.45158033]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -2239.9290898765335
# Epoch 10
# -999.4569223990698
# Epoch 20
# -988.3950104466321
# Epoch 30
# -976.6765313405346
# Epoch 40
# -972.3893177581762
# Epoch 50
# -971.1466258364629
# Epoch 60
# -970.7501528856205
# Epoch 70
# -970.6296759497282
# Epoch 80
# -970.5939784253275
# The loglikelihood improvement falls below threshold, training terminates at epoch 86!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.99964016e-01 3.59836184e-05]
#  [6.39454493e-02 9.36054551e-01]]
# 5) The emission probability matrix E:
# [array([[0.03618953, 0.96381047],
#        [0.17033284, 0.82966716]])]
# 6) The initial state probability Pi:
# [6.60668578e-07 9.99999339e-01]
#
# -----------------------------------------
#  KC: 5
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.62473537, 0.37526463],
#        [0.52371153, 0.47628847]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -4766.3972073066725
# Epoch 10
# -2329.40896850519
# Epoch 20
# -2311.3542868859295
# Epoch 30
# -2299.0909250547593
# Epoch 40
# -2292.7892420889243
# Epoch 50
# -2290.588106018411
# Epoch 60
# -2289.773151942802
# Epoch 70
# -2289.4363716199555
# Epoch 80
# -2289.295993256285
# Epoch 90
# -2289.237700133314
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.99909823e-01 9.01774443e-05]
#  [1.81211515e-02 9.81878848e-01]]
# 5) The emission probability matrix E:
# [array([[0.2090108 , 0.7909892 ],
#        [0.07530131, 0.92469869]])]
# 6) The initial state probability Pi:
# [1.69808671e-04 9.99830191e-01]
#
# -----------------------------------------
#  KC: 6
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.16210089, 0.83789911],
#        [0.73490536, 0.26509464]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -3258.8918558120413
# Epoch 10
# -2620.134874440604
# Epoch 20
# -2616.0100564733625
# Epoch 30
# -2611.1559193592775
# Epoch 40
# -2606.712729642166
# Epoch 50
# -2602.5871868079994
# Epoch 60
# -2599.1723235990266
# Epoch 70
# -2597.1398679282297
# Epoch 80
# -2596.222821714733
# Epoch 90
# -2595.8272315594804
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.95841445 0.04158555]
#  [0.00238319 0.99761681]]
# 5) The emission probability matrix E:
# [array([[0.08289316, 0.91710684],
#        [0.19622765, 0.80377235]])]
# 6) The initial state probability Pi:
# [1.00000000e+00 7.77246349e-11]
#
# 7 107
# ======================================================
# -----------------------------------------
#  KC: 0
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.48142527, 0.51857473],
#        [0.96833752, 0.03166248]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -728.7532951431791
# Epoch 10
# -321.0064856422293
# Epoch 20
# -320.8419674968896
# Epoch 30
# -319.8958493693711
# Epoch 40
# -314.77382226346026
# Epoch 50
# -313.703899888149
# Epoch 60
# -313.8449303597877
# Epoch 70
# -314.50789111547834
# Epoch 80
# -315.18016346139467
# Epoch 90
# -315.6741120370948
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.28390837 0.71609163]
#  [0.99868481 0.00131519]]
# 5) The emission probability matrix E:
# [array([[0.02468437, 0.97531563],
#        [0.27962856, 0.72037144]])]
# 6) The initial state probability Pi:
# [0.59609551 0.40390449]
#
# -----------------------------------------
#  KC: 1
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.40991462, 0.59008538],
#        [0.81366856, 0.18633144]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -1434.7941265876939
# Epoch 10
# -782.5436212308633
# Epoch 20
# -774.8673711059572
# Epoch 30
# -770.5661231373786
# Epoch 40
# -769.2575513329729
# Epoch 50
# -768.7942126135307
# Epoch 60
# -768.4867900578133
# Epoch 70
# -768.1577017183303
# Epoch 80
# -767.9086979099253
# Epoch 90
# -767.7916481575805
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.07519026e-01 9.24809745e-02]
#  [4.67734701e-05 9.99953227e-01]]
# 5) The emission probability matrix E:
# [array([[0.04492741, 0.95507259],
#        [0.19966486, 0.80033514]])]
# 6) The initial state probability Pi:
# [0.88040346 0.11959654]
#
# -----------------------------------------
#  KC: 2
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.60771708, 0.39228292],
#        [0.03833671, 0.96166329]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -3136.4751723445643
# Epoch 10
# -2861.8073803278935
# Epoch 20
# -2846.1238613941514
# Epoch 30
# -2833.448088568249
# Epoch 40
# -2827.4816261673145
# Epoch 50
# -2825.394382316518
# Epoch 60
# -2824.7436291975323
# Epoch 70
# -2824.5428276190473
# Epoch 80
# -2824.480251549736
# Epoch 90
# -2824.4606473358986
# The loglikelihood improvement falls below threshold, training terminates at epoch 91!
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.99974627e-01 2.53730469e-05]
#  [1.97492939e-02 9.80250706e-01]]
# 5) The emission probability matrix E:
# [array([[0.23579401, 0.76420599],
#        [0.09165032, 0.90834968]])]
# 6) The initial state probability Pi:
# [3.91717922e-14 1.00000000e+00]
#
# -----------------------------------------
#  KC: 3
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.24775766, 0.75224234],
#        [0.48677102, 0.51322898]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -614.7772579051795
# Epoch 10
# -487.45417602541886
# Epoch 20
# -487.31850200903824
# Epoch 30
# -487.0545663484941
# Epoch 40
# -486.60301026163813
# Epoch 50
# -485.88397544597206
# Epoch 60
# -484.5922474889344
# Epoch 70
# -481.2529217809042
# Epoch 80
# -474.08150206603443
# Epoch 90
# -472.01521476163424
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.2491351  0.7508649 ]
#  [0.05612032 0.94387968]]
# 5) The emission probability matrix E:
# [array([[0.00865355, 0.99134645],
#        [0.18333116, 0.81666884]])]
# 6) The initial state probability Pi:
# [0.99727848 0.00272152]
#
# -----------------------------------------
#  KC: 4
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.87495231, 0.12504769],
#        [0.26538119, 0.73461881]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -1566.0736171400038
# Epoch 10
# -971.6012206664367
# Epoch 20
# -971.3413110975486
# Epoch 30
# -971.0091551804895
# Epoch 40
# -969.980679253008
# Epoch 50
# -967.2044011911006
# Epoch 60
# -962.3076530191539
# Epoch 70
# -955.3574940026971
# Epoch 80
# -951.2549427038257
# Epoch 90
# -950.2480606821724
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[9.29378692e-01 7.06213080e-02]
#  [4.61196486e-04 9.99538804e-01]]
# 5) The emission probability matrix E:
# [array([[0.15982205, 0.84017795],
#        [0.04501049, 0.95498951]])]
# 6) The initial state probability Pi:
# [0.99853305 0.00146695]
#
# -----------------------------------------
#  KC: 5
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.46182008, 0.53817992],
#        [0.50069769, 0.49930231]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -4126.221796176317
# Epoch 10
# -2275.600781755153
# Epoch 20
# -2262.121522233448
# Epoch 30
# -2255.667111593223
# Epoch 40
# -2251.080591071785
# Epoch 50
# -2248.7086113918845
# Epoch 60
# -2247.6916807218317
# Epoch 70
# -2247.1605602571035
# Epoch 80
# -2246.710663448605
# Epoch 90
# -2246.318024376094
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.97428647 0.02571353]
#  [0.00133004 0.99866996]]
# 5) The emission probability matrix E:
# [array([[0.05618915, 0.94381085],
#        [0.17978926, 0.82021074]])]
# 6) The initial state probability Pi:
# [0.8902321 0.1097679]
#
# -----------------------------------------
#  KC: 6
#
#
# ************************
# HMM Initialization
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.86 0.14]
#  [0.09 0.91]]
# 5) The emission probability matrix E:
# [array([[0.64082101, 0.35917899],
#        [0.352293  , 0.647707  ]])]
# 6) The initial state probability Pi:
# [0.5 0.5]
#
# Epoch 0
# -3649.196726443109
# Epoch 10
# -2594.920594585564
# Epoch 20
# -2588.110564039048
# Epoch 30
# -2582.9176704691645
# Epoch 40
# -2578.953412461651
# Epoch 50
# -2576.3618518101744
# Epoch 60
# -2575.047759387446
# Epoch 70
# -2574.4869665577844
# Epoch 80
# -2574.254947331591
# Epoch 90
# -2574.1532242305416
#
#
# ************************
# After training
# ************************
#
# 1) Numerber of hidden states:2
# 2) Number of observable symbols:[['0', '1']]	(0: wrong, 1: correct)
# 3) The symbol mapping in HMM:[{'0': 0, '1': 1}]	(0: Not learned, 1: Learned)
# 4) The transition proability matrix T:
# [[0.99281122 0.00718878]
#  [0.04066304 0.95933696]]
# 5) The emission probability matrix E:
# [array([[0.2045738 , 0.7954262 ],
#        [0.08099647, 0.91900353]])]
# 6) The initial state probability Pi:
# [1.6003077e-10 1.0000000e+00]
#
# 7 108
# CPU times: user 10min 28s, sys: 1.9 s, total: 10min 30s
# Wall time: 10min 20s

# %% [markdown]
# ### Results

# %%
# test code data ###
# qlg_test_pred, post_test_pred = [0]*len(qlg_y), [0.5]*len(post_y)
# qlg_test_actual, post_test_actual = qlg_y, post_y
print( " ")
print ("<<<<<<< student learning gain")
print ("Training accuracy:" + str(accuracy_score(qlg_train_actual, qlg_train_pred)))
print ("Accuracy: " + str(accuracy_score(qlg_test_actual, qlg_test_pred)))


# flip P and N here because we care about the low learning gain group: qlg = 0
qlg_test_actual = [1 if each == 0 else 0 for each in qlg_test_actual]       
qlg_test_pred = [1 if each == 0 else 0 for each in qlg_test_pred]


print( "f1_score: " + str(f1_score(qlg_test_actual, qlg_test_pred)))
print ("Recall: " + str(recall_score(qlg_test_actual, qlg_test_pred)))
print ("AUC: " + str(roc_auc_score(qlg_test_actual, qlg_test_pred)))
print ("Confusion Matrix: ")
print (confusion_matrix(qlg_test_actual, qlg_test_pred))
print (" ")
print ("<<<<<<< student modeling")
print ("Training MSE: ", mean_squared_error(post_train_actual, post_train_pred))
print ("Test MSE: ", mean_squared_error(post_test_actual, post_test_pred))
# Out:
#
# <<<<<<< student learning gain
# Training accuracy:0.6305970149253731
# Accuracy: 0.5746268656716418
# f1_score: 0.6415094339622641
# Recall: 0.6891891891891891
# AUC: 0.5612612612612612
# Confusion Matrix:
# [[26 34]
#  [23 51]]
#
# <<<<<<< student modeling
# Training MSE:  1.3146155446625902
# Test MSE:  1.4362419524563843

# %% [markdown]
# ### Report your observation from
#  - the HMM model parameters after training as compared to the initial parameters (select one KC in the first fold of 5-CV).
#  - changing the initial parameters of the HMM model.
#  - comparing parameters of HMMs trained for different KCs.
