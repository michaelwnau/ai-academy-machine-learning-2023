# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelwnau/ai-academy-machine-learning-2023/blob/main/W10S2_RecSys_SVDTuning_Sol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Week 10 - Session 2 : Recommendation Sytem - Grid Search
#
#  - Finding the best parameter for MovieLens-100k data with GridSearchCV

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dependencies
# - Install package: surprise  (pip install surprise)

# %%
# Dependencies
# !pip install surprise
# or
# !conda install -c conda-forge scikit-surprise
# Out:
# Collecting surprise
#   Downloading surprise-0.1-py2.py3-none-any.whl (1.8 kB)
# Collecting scikit-surprise (from surprise)
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.11.4)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163768 sha256=66ef4399b184cc85db5f422eae27cadff76a29585169c7083be9ef77846ce650
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise, surprise
# Successfully installed scikit-surprise-1.1.3 surprise-0.1

# %% [markdown]
# ## 1. Load Data

# %%
import numpy as np
import pandas as pd
from surprise import SVD
from surprise import Reader
from surprise import Dataset
from surprise.model_selection import GridSearchCV
from surprise import accuracy

df = pd.read_csv("/content/drive/MyDrive/ai-academy-machine-learning-2023/week-10/2_W10S2_Code_RecSys2_SVDTuning/2_W10S2_Code_RecSys2_SVDTuning/ml-latest-small/ratings.csv")
df.columns = ['userID', 'itemID', 'rating', 'timestamp']

# %%
df.head()
# Out:
#    userID  itemID  rating  timestamp
# 0       1       1     4.0  964982703
# 1       1       3     4.0  964981247
# 2       1       6     4.0  964982224
# 3       1      47     5.0  964983815
# 4       1      50     5.0  964982931

# %% [markdown]
# ## 2. Parameter Search - Tuning
#
# - Set up a movie recommender system using the matrix factorization.SVD algorithm, which was popularized by Simon Funk during the Netﬂix Prize.
# - Tune your model with 3-fold cross validation with the following methods.
# - surprise.SVD : https://surprise.readthedocs.io/en/stable/matrix_factorization.html
# - paper: https://datajobs.com/data-science-repo/Recommender-Systems-[Netflix].pdf

# %%
def tuning(df, target_rating, rating_scale, n_jobs):
    # A reader is still needed but only the rating_scale param is requiered.
    reader = Reader(rating_scale=rating_scale)

    # The columns must correspond to user id, item id and ratings (in that order).
    data = Dataset.load_from_df(df[['userID', 'itemID', target_rating]], reader)

    # SVD parameters
    # 'n_factors': number of latent factors
    # 'n_epochs': The number of iteration of the SGD procedure.
    # 'lr_all': learning rate
    # 'reg_all': regularization

    param_grid = {'n_factors': [100, 200, 300], 'n_epochs': [20, 30], 'lr_all': [0.005, 0.01],
                  'reg_all': [0.02, 0.2]}

    # SVD : the method for recommendation
    # param_grid: parameter search space
    # measures: The performance measures to compute.
    # cv: cross validation
    # n_jobs: The maximum number of parallel training procedures.

    gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3, n_jobs=n_jobs, joblib_verbose=50)
    gs.fit(data)

    # best RMSE score
    print(gs.best_score['rmse'])

    # combination of parameters that gave the best RMSE score
    print(gs.best_params['rmse'])
    return data, gs

# %%
data, gs = tuning(df, target_rating = 'rating', rating_scale = (1,5), n_jobs = 6)
# Out:
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=6)]: Done   6 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=6)]: Done   7 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=6)]: Done   8 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=6)]: Done   9 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=6)]: Done  10 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=6)]: Done  11 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=6)]: Done  12 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=6)]: Done  13 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=6)]: Done  14 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=6)]: Done  15 tasks      | elapsed:   37.6s
# [Parallel(n_jobs=6)]: Done  16 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=6)]: Done  17 tasks      | elapsed:   38.6s
# [Parallel(n_jobs=6)]: Done  18 tasks      | elapsed:   43.5s
# [Parallel(n_jobs=6)]: Done  19 tasks      | elapsed:   47.7s
# [Parallel(n_jobs=6)]: Done  20 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=6)]: Done  21 tasks      | elapsed:   51.4s
# [Parallel(n_jobs=6)]: Done  22 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=6)]: Done  23 tasks      | elapsed:   53.9s
# [Parallel(n_jobs=6)]: Done  24 tasks      | elapsed:   58.0s
# [Parallel(n_jobs=6)]: Done  25 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=6)]: Done  26 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=6)]: Done  27 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=6)]: Done  28 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=6)]: Done  29 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=6)]: Done  30 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=6)]: Done  31 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  32 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  33 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  34 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  35 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  36 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=6)]: Done  37 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=6)]: Done  39 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=6)]: Done  40 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=6)]: Done  41 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  42 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done  43 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=6)]: Done  44 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=6)]: Done  45 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=6)]: Done  46 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=6)]: Done  47 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=6)]: Done  48 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=6)]: Done  49 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  50 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  51 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  52 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=6)]: Done  53 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=6)]: Done  54 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=6)]: Done  55 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=6)]: Done  56 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=6)]: Done  57 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=6)]: Done  58 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  59 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  60 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=6)]: Done  61 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=6)]: Done  63 out of  72 | elapsed:  3.0min remaining:   25.5s
# [Parallel(n_jobs=6)]: Done  65 out of  72 | elapsed:  3.0min remaining:   19.6s
# [Parallel(n_jobs=6)]: Done  67 out of  72 | elapsed:  3.3min remaining:   15.0s
# [Parallel(n_jobs=6)]: Done  69 out of  72 | elapsed:  3.4min remaining:    8.8s
# [Parallel(n_jobs=6)]: Done  72 out of  72 | elapsed:  3.4min finished
# 0.8725036934960766
# {'n_factors': 200, 'n_epochs': 30, 'lr_all': 0.01, 'reg_all': 0.2}

# %% [markdown]
# ### GridSearchCV Result
#
#  - Showing the overall tuning results from the above 3-fold cross validation. (RMSE/MAE from all folds)

# %%
results_df = pd.DataFrame.from_dict(gs.cv_results)
results_df
# Out:
#     split0_test_rmse  split1_test_rmse  split2_test_rmse  mean_test_rmse  \
# 0           0.881631          0.882175          0.881182        0.881663
# 1           0.878713          0.878020          0.878667        0.878467
# 2           0.888985          0.885889          0.884655        0.886510
# 3           0.874513          0.874329          0.875119        0.874654
# 4           0.884734          0.881454          0.882038        0.882742
# 5           0.875345          0.875286          0.875673        0.875435
# 6           0.892475          0.891654          0.890823        0.891651
# 7           0.872950          0.873127          0.873903        0.873327
# 8           0.888048          0.887495          0.887796        0.887780
# 9           0.879170          0.877846          0.878987        0.878668
# 10          0.889049          0.886902          0.887702        0.887885
# 11          0.873857          0.873993          0.875024        0.874291
# 12          0.889443          0.890409          0.888926        0.889592
# 13          0.875672          0.875030          0.875854        0.875518
# 14          0.886668          0.888132          0.884466        0.886422
# 15          0.872322          0.872068          0.873121        0.872504
# 16          0.892220          0.891676          0.891452        0.891783
# 17          0.879194          0.878534          0.879687        0.879138
# 18          0.887813          0.889742          0.889564        0.889040
# 19          0.874097          0.873417          0.875212        0.874242
# 20          0.891066          0.889464          0.892622        0.891050
# 21          0.875605          0.874880          0.876031        0.875505
# 22          0.885058          0.885470          0.881918        0.884149
# 23          0.872046          0.871913          0.873625        0.872528
#
#     std_test_rmse  rank_test_rmse  split0_test_mae  split1_test_mae  \
# 0        0.000406              13         0.678864         0.679008
# 1        0.000316              10         0.678105         0.676317
# 2        0.001821              17         0.682934         0.680652
# 3        0.000338               6         0.674157         0.672983
# 4        0.001429              14         0.680365         0.676670
# 5        0.000170               7         0.675090         0.673560
# 6        0.000674              23         0.686222         0.685527
# 7        0.000414               3         0.672703         0.671658
# 8        0.000226              18         0.684993         0.682732
# 9        0.000586              11         0.678793         0.676222
# 10       0.000886              19         0.683832         0.680752
# 11       0.000521               5         0.673881         0.672710
# 12       0.000615              21         0.684963         0.684909
# 13       0.000354               9         0.675215         0.673425
# 14       0.001507              16         0.681760         0.682444
# 15       0.000449               1         0.672137         0.670807
# 16       0.000322              24         0.687620         0.686413
# 17       0.000472              12         0.678862         0.676857
# 18       0.000870              20         0.683916         0.684845
# 19       0.000740               4         0.674055         0.672147
# 20       0.001289              22         0.686355         0.682541
# 21       0.000475               8         0.675374         0.673403
# 22       0.001586              15         0.680907         0.680191
# 23       0.000777               2         0.671954         0.670668
#
#     split2_test_mae  mean_test_mae  ...  rank_test_mae  mean_fit_time  \
# 0          0.677707       0.678526  ...             13       5.066942
# 1          0.677435       0.677286  ...             10       6.807975
# 2          0.678761       0.680782  ...             16       9.226729
# 3          0.673941       0.673694  ...              6       7.211572
# 4          0.678558       0.678531  ...             14      11.658336
# 5          0.674537       0.674396  ...              7      12.451009
# 6          0.685835       0.685861  ...             23       9.593564
# 7          0.672871       0.672411  ...              3      11.458215
# 8          0.683542       0.683756  ...             19      10.743034
# 9          0.677887       0.677634  ...             11      10.193856
# 10         0.682438       0.682341  ...             18      12.603620
# 11         0.673954       0.673515  ...              5      11.089472
# 12         0.684159       0.684677  ...             21      17.318124
# 13         0.674584       0.674408  ...              8      16.896751
# 14         0.680775       0.681659  ...             17      16.812783
# 15         0.672277       0.671740  ...              2      16.653680
# 16         0.687361       0.687131  ...             24      15.773338
# 17         0.678181       0.677967  ...             12      14.892038
# 18         0.684547       0.684436  ...             20      16.106075
# 19         0.674073       0.673425  ...              4      15.219573
# 20         0.688559       0.685818  ...             22      21.944395
# 21         0.674709       0.674495  ...              9      23.061488
# 22         0.679292       0.680130  ...             15      22.412637
# 23         0.672552       0.671725  ...              1      19.662261
#
#     std_fit_time  mean_test_time  std_test_time  \
# 0       0.080472        1.171917       0.088817
# 1       1.855632        1.906147       0.436160
# 2       0.281512        1.515217       0.107656
# 3       0.972513        1.620541       0.348462
# 4       0.640538        2.172846       0.248948
# 5       0.493842        1.530296       0.121733
# 6       0.597389        2.275002       0.245859
# 7       0.656762        2.252803       0.546809
# 8       0.932133        1.537446       0.201584
# 9       1.499117        2.195036       0.445272
# 10      0.191928        1.406735       0.063788
# 11      1.019314        1.844795       0.390188
# 12      0.081436        1.518552       0.041774
# 13      0.045448        1.945468       0.362681
# 14      0.066965        1.488209       0.172423
# 15      0.273190        1.975348       0.379123
# 16      0.080674        1.398148       0.165468
# 17      0.569007        1.947647       0.417894
# 18      0.038998        1.569695       0.112654
# 19      1.112500        2.066028       0.410312
# 20      0.613822        2.440491       0.421375
# 21      0.520417        2.240601       0.579782
# 22      1.308879        1.259347       0.060535
# 23      1.404421        0.601388       0.275119
#
#                                                params param_n_factors  \
# 0   {'n_factors': 100, 'n_epochs': 20, 'lr_all': 0...             100
# 1   {'n_factors': 100, 'n_epochs': 20, 'lr_all': 0...             100
# 2   {'n_factors': 100, 'n_epochs': 20, 'lr_all': 0...             100
# 3   {'n_factors': 100, 'n_epochs': 20, 'lr_all': 0...             100
# 4   {'n_factors': 100, 'n_epochs': 30, 'lr_all': 0...             100
# 5   {'n_factors': 100, 'n_epochs': 30, 'lr_all': 0...             100
# 6   {'n_factors': 100, 'n_epochs': 30, 'lr_all': 0...             100
# 7   {'n_factors': 100, 'n_epochs': 30, 'lr_all': 0...             100
# 8   {'n_factors': 200, 'n_epochs': 20, 'lr_all': 0...             200
# 9   {'n_factors': 200, 'n_epochs': 20, 'lr_all': 0...             200
# 10  {'n_factors': 200, 'n_epochs': 20, 'lr_all': 0...             200
# 11  {'n_factors': 200, 'n_epochs': 20, 'lr_all': 0...             200
# 12  {'n_factors': 200, 'n_epochs': 30, 'lr_all': 0...             200
# 13  {'n_factors': 200, 'n_epochs': 30, 'lr_all': 0...             200
# 14  {'n_factors': 200, 'n_epochs': 30, 'lr_all': 0...             200
# 15  {'n_factors': 200, 'n_epochs': 30, 'lr_all': 0...             200
# 16  {'n_factors': 300, 'n_epochs': 20, 'lr_all': 0...             300
# 17  {'n_factors': 300, 'n_epochs': 20, 'lr_all': 0...             300
# 18  {'n_factors': 300, 'n_epochs': 20, 'lr_all': 0...             300
# 19  {'n_factors': 300, 'n_epochs': 20, 'lr_all': 0...             300
# 20  {'n_factors': 300, 'n_epochs': 30, 'lr_all': 0...             300
# 21  {'n_factors': 300, 'n_epochs': 30, 'lr_all': 0...             300
# 22  {'n_factors': 300, 'n_epochs': 30, 'lr_all': 0...             300
# 23  {'n_factors': 300, 'n_epochs': 30, 'lr_all': 0...             300
#
#     param_n_epochs  param_lr_all  param_reg_all
# 0               20         0.005           0.02
# 1               20         0.005           0.20
# 2               20         0.010           0.02
# 3               20         0.010           0.20
# 4               30         0.005           0.02
# 5               30         0.005           0.20
# 6               30         0.010           0.02
# 7               30         0.010           0.20
# 8               20         0.005           0.02
# 9               20         0.005           0.20
# 10              20         0.010           0.02
# 11              20         0.010           0.20
# 12              30         0.005           0.02
# 13              30         0.005           0.20
# 14              30         0.010           0.02
# 15              30         0.010           0.20
# 16              20         0.005           0.02
# 17              20         0.005           0.20
# 18              20         0.010           0.02
# 19              20         0.010           0.20
# 20              30         0.005           0.02
# 21              30         0.005           0.20
# 22              30         0.010           0.02
# 23              30         0.010           0.20
#
# [24 rows x 21 columns]

# %% [markdown]
# ## 3. Evaluate the model
#
# - Here we evaluate the model with `RMSE`.

# %%
# %%time
# 1) Train the best model with full trainset.
trainset = data.build_full_trainset()
algo = gs.best_estimator['rmse']
algo.fit(trainset)

# 2) Make prediction using the testset which are NOT in the training set.
testset = trainset.build_anti_testset()
predictions = algo.test(testset)
accuracy.rmse(predictions)
# Out:
# RMSE: 0.5064
# CPU times: user 1min 8s, sys: 4.27 s, total: 1min 12s
# Wall time: 1min 12s
# 0.5063952801124072

# %% [markdown]
# ### Questions
# - Select one specific user ID and recommend movies:
# https://surprise.readthedocs.io/en/stable/FAQ.html
